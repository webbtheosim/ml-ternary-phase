# %%
# %load_ext autoreload
# %autoreload 2

# %%
DATA_DIR = "/scratch/gpfs/sj0161/mlphase/data/"
MODEL_PATH = "/scratch/gpfs/sj0161/mlphase/model/"
TRAIN_RESULT_DIR = "/scratch/gpfs/sj0161/mlphase/pickle/"
OPT_RESULT_DIR = "/scratch/gpfs/sj0161/mlphase/opt_pickle/"

RESULT_DIR = "/home/sj0161/mlphase/result_pickle/"
PLOT_DIR = "/home/sj0161/mlphase/figure/"
CSV_DIR = "/home/sj0161/mlphase/result_csv/"


class Args:
    def __init__(self):
        self.PLOT_DIR = PLOT_DIR
        self.OPT_RESULT_DIR = OPT_RESULT_DIR
        self.DATA_DIR = DATA_DIR
        
        
args = Args()

# %%
from mlphase.run_opt import main

# %% [markdown]
# Takes about 40 secs to generate one figure.
#
#
# pickle_file in {
#         "/scratch/gpfs/sj0161/mlphase/pickle/MLPHASEOUTER-1-1-5000-500-0.001-0-1.0-256-base.pickle",
#         "/scratch/gpfs/sj0161/mlphase/pickle/MLPHASEOUTER-1-1-5000-500-0.001-0-0.1-256-base.pickle",
#         "/scratch/gpfs/sj0161/mlphase/pickle/MLPHASEOUTER-1-1-5000-500-0.001-0-1.0-256-softbase.pickle",
#         "/scratch/gpfs/sj0161/mlphase/pickle/MLPHASEOUTER-1-1-5000-500-0.001-0-0.1-256-softbase.pickle",
#         "/scratch/gpfs/sj0161/mlphase/pickle/MLPHASEOUTER-1-1-5000-500-0.001-0-0.1-256-softpir.pickle",
#         "/scratch/gpfs/sj0161/mlphase/pickle/MLPHASEOUTER-1-1-5000-500-0.001-0-1.0-256-softpir.pickle",
#     }
#
# index in {0, 207}

# %%
pickle_file = "/scratch/gpfs/sj0161/mlphase/pickle/MLPHASEOUTER-1-1-5000-500-0.001-0-1.0-256-softbase.pickle"
index = 0

main(
    args=args,
    pickle_file=pickle_file,
    opt_result_dir=args.OPT_RESULT_DIR,
    index=index,
    plot_fig=True,
    rerun=False,
)
# Out:
# OPT-1-1-5000-500-0.001-0-1.0-256-softbase-5.pickle
# /scratch/gpfs/sj0161/mlphase/fig_ternary/1-1-1.0-softbase-5_post.png saved ...
# /scratch/gpfs/sj0161/mlphase/fig_ternary/1-1-1.0-softbase-5_ml_new.png saved ...
# /scratch/gpfs/sj0161/mlphase/fig_ternary/1-1-1.0-softbase-5_cls.png saved ...
# figure done

# %%
# %%time
pickle_file = "/scratch/gpfs/sj0161/mlphase/pickle/MLPHASEOUTER-1-1-5000-500-0.001-0-0.1-256-base.pickle"
index = 1

main(args=args,
     pickle_file=pickle_file,
     opt_result_dir=args.OPT_RESULT_DIR,
     index=index,
     plot_fig=True,
     rerun=False)
# Out:
# OPT-1-1-5000-500-0.001-0-0.1-256-base-8.pickle
# /scratch/gpfs/sj0161/mlphase/fig_ternary/1-1-0.1-base-8_post.png saved ...
# /scratch/gpfs/sj0161/mlphase/fig_ternary/1-1-0.1-base-8_ml_new.png saved ...
# /scratch/gpfs/sj0161/mlphase/fig_ternary/1-1-0.1-base-8_cls.png saved ...
# figure done
# CPU times: user 1min 44s, sys: 297 ms, total: 1min 44s
# Wall time: 1min 44s
